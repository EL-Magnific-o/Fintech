# %%
import pandas as pd

# %%
df = pd.read_csv('kickstarter_sample.csv')

# %%
df.head()
# Out:
#             created_at  backers_count  \
# 0  2009-04-25 05:37:50             25
# 1  2009-08-25 18:21:02             36
# 2  2009-08-30 16:57:43             82
# 3  2009-09-14 23:58:49             10
# 4  2009-10-11 20:28:44            156
#
#                                                blurb  \
# 0  This is a project to create a free iPhone app ...
# 1  Your donation will go directly to the purchase...
# 2  Exploring a classic style of portraiture and f...
# 3  World renowned artist collective, Bandwagon, s...
# 4  Six series of 100 signed and numbered tabletop...
#
#                                             category  \
# 0  {"id":51,"name":"Software","analytics_name":"S...
# 1  {"id":23,"name":"Painting","analytics_name":"P...
# 2  {"id":23,"name":"Painting","analytics_name":"P...
# 3  {"id":23,"name":"Painting","analytics_name":"P...
# 4  {"id":25,"name":"Sculpture","analytics_name":"...
#
#    converted_pledged_amount country country_displayable_name  \
# ...

# %%
df.tail()
# Out:
#                created_at  backers_count  \
# 6953  2021-05-08 19:57:26              4
# 6954  2021-05-08 19:57:26              4
# 6955  2021-05-09 04:06:34             18
# 6956  2021-05-09 14:32:09              1
# 6957  2021-05-10 02:24:04              2
#
#                                                   blurb  \
# 6953         "Once Upon a Time in...Hollywood"- Parody.
# 6954         "Once Upon a Time in...Hollywood"- Parody.
# 6955  NEW Variant Covers for War Angels Issues 4 and 5!
# 6956             Taylor Swift Every Era Soft Enamel Pin
# 6957  Tale of Xestuoria is a fantasy podcast, full o...
#
#                                                category  \
# 6953  {"id":292,"name":"Comedy","analytics_name":"Co...
# 6954  {"id":292,"name":"Comedy","analytics_name":"Co...
# 6955  {"id":250,"name":"Comic Books","analytics_name...
# 6956  {"id":1,"name":"Art","analytics_name":"Art","s...
# 6957  {"id":239,"name":"Radio & Podcasts","analytics...
#
# ...

# %%
df.shape
# Out:
# (6958, 39)

# %%
df.columns
# Out:
# Index(['created_at', 'backers_count', 'blurb', 'category',
#        'converted_pledged_amount', 'country', 'country_displayable_name',
#        'creator', 'currency', 'currency_symbol', 'currency_trailing_code',
#        'current_currency', 'deadline', 'disable_communication', 'friends',
#        'fx_rate', 'goal', 'id', 'is_backing', 'is_starrable', 'is_starred',
#        'launched_at', 'location', 'name', 'permissions', 'photo', 'pledged',
#        'profile', 'slug', 'source_url', 'spotlight', 'staff_pick', 'state',
#        'state_changed_at', 'static_usd_rate', 'urls', 'usd_exchange_rate',
#        'usd_pledged', 'usd_type'],
#       dtype='object')

# %%
df.describe()
# Out:
#        backers_count  converted_pledged_amount      deadline      fx_rate  \
# count    6958.000000              6.958000e+03  6.958000e+03  6958.000000
# mean      217.339609              1.984901e+04  1.513298e+09     1.015578
# std       969.073292              9.207770e+04  8.912273e+07     0.254118
# min         1.000000              0.000000e+00  1.247555e+09     0.009115
# 25%        30.000000              1.552750e+03  1.442452e+09     1.000000
# 50%        66.000000              4.389500e+03  1.531432e+09     1.000000
# 75%       158.000000              1.201725e+04  1.596080e+09     1.000000
# max     50285.000000              3.310872e+06  1.626047e+09     1.410859
#
#                goal            id   launched_at       pledged  \
# count  6.958000e+03  6.958000e+03  6.958000e+03  6.958000e+03
# mean   1.435394e+04  1.057633e+09  1.510605e+09  6.840051e+04
# std    1.216604e+05  6.224102e+08  8.913647e+07  2.838251e+06
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6958 entries, 0 to 6957
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   created_at                6958 non-null   object
#  1   backers_count             6958 non-null   int64
#  2   blurb                     6958 non-null   object
#  3   category                  6958 non-null   object
#  4   converted_pledged_amount  6958 non-null   int64
#  5   country                   6958 non-null   object
#  6   country_displayable_name  6958 non-null   object
#  7   creator                   6958 non-null   object
#  8   currency                  6958 non-null   object
#  9   currency_symbol           6958 non-null   object
#  10  currency_trailing_code    6958 non-null   bool
#  11  current_currency          6958 non-null   object
#  12  deadline                  6958 non-null   int64
#  13  disable_communication     6958 non-null   bool
# ...
